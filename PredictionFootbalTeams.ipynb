# %% [markdown]
# ##Predicting the winner of the Premiere League matches (Football)

# %% [markdown]
# In this notebook I'm going to predict who's going to win each football match in the English Premier League using a machine learning model called `a Random Forest`
#
# The notebook will include:
#
# *   Loading and cleaning data with Pandas libraru
# *   Apply a machine learning model
# *   Measuring how well this algorithm really works
# *   Improve the algorithm
# *   Getting some results

# %%
# Installing pandas library

import pandas as pd

# Reading in the initial data

matches = pd.read_csv("https://raw.githubusercontent.com/dataquestio/project-walkthroughs/master/football_matches/matches.csv", index_col=0)

# %%
# Looking for the first 6 rows of data

matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# ...

# %%
#the DataFrame is made up of 1389 rows and 27 columns of data

matches.shape
# Out:
# (1389, 27)

# %%
38 * 20 * 2 #In the English Premier League, there are 20 teams, and each team plays 38 matches; data for two seasons
# Out:
# 1520

# %%
#How many matches we had for each team in df

matches["team"].value_counts()
# Out:
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: team, dtype: int64

# %%
#All Liverpool games in DataFrame

matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W  4.0
# 2   2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 4   2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W  3.0
# 6   2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 7   2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# 9   2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 11  2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W  2.0
# 13  2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D  1.0
# 14  2020-11-22  19:15  Premier League   Matchweek 9  Sun  Home      W  3.0
# 16  2020-11-28  12:30  Premier League  Matchweek 10  Sat  Away      D  1.0
# 18  2020-12-06  19:15  Premier League  Matchweek 11  Sun  Home      W  4.0
# ...

# %%
#Looking how many matches were in every matchweek for 2 seasons 

matches["round"].value_counts()
# Out:
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: round, dtype: int64

# %%
#Types of data

matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
#Convert data into datetime type (Algoithm can't work with data that is not numeric)

matches["date"] = pd.to_datetime(matches["date"])
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek
matches["result"] = (matches["result"] == "w").astype("int")

# %% [raw]
# Creating predictors (#Predictors that converting datatype into numbers(int))

# %%
#Updated data

matches
# Out:
#          date   time            comp         round  day venue  result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away       0  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home       0  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home       0  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away       0  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home       0  0.0
# ..        ...    ...             ...           ...  ...   ...     ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away       0  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home       0  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away       0  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away       0  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home       0  1.0
#
# ...

# %%
#Setting up a target for machine learning model. The target is whether the team win or not

matches["target"] = (matches["result"] == "W").astype("int")

# %%
#Importing Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier

# %%
#Initialazing RandomForestClassifier

rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
#Creating date type data for training

train = matches[matches["date"] < '2022-01-01']

# %%
#Declaring the test dataset

test = matches[matches["date"] > '2022-01-01']

# %%
#Creating a variable with a list with predictors

predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
#Fitting Random Forest model for predicting the target using trained predictors 

rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
#Generating predictions using predict methods

preds = rf.predict(test[predictors])

# %%
#Import accuracy_score what would tell what percentage of the time prediction is accurate

from sklearn.metrics import accuracy_score

# %%
error = accuracy_score(test["target"], preds)

# %%
#Looking for an accuracy

error
# Out:
# 0.6123188405797102

# %%
#Creating a DataFrame which will combine actual and predicted values

combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
#Creating a two-way table that will show when predicted zero or one actually happened 

pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          141  31
# 1           76  28

# %%
#Import a metric that tells what percentage of time did the team actually win

from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.4745762711864407

# %%
#Split matches df up by team for computing team averages for team perfomance. Creating one df for every squad in data

grouped_matches = matches.groupby("team")

# %%
#All matches with Manchester City

group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
group
# Out:
#          date   time            comp         round  day venue  result   gf  \
# 0  2020-09-21  20:15  Premier League   Matchweek 2  Mon  Away       0  3.0
# 2  2020-09-27  16:30  Premier League   Matchweek 3  Sun  Home       0  2.0
# 4  2020-10-03  17:30  Premier League   Matchweek 4  Sat  Away       0  1.0
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home       0  1.0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away       0  1.0
# ..        ...    ...             ...           ...  ...   ...     ...  ...
# 42 2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away       0  0.0
# 44 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away       0  2.0
# 46 2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home       0  2.0
# 49 2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home       0  3.0
# 50 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home       0  5.0
#
# ...

# %%
#Taking a group in, set of columns what we want to compute rolling averages for and then it'll take a set of new columns that we want to assign the rolling averages

def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
#Taking columns for computing rolling averages 

cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]

#Adding rolling part to the column
new_cols = [f"{c}_rolling" for c in cols]

# %%
#Calling rolling_averages for a single group

rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue  result   gf  \
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home       0  1.0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away       0  1.0
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away       0  1.0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home       0  1.0
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away       0  0.0
# ..        ...    ...             ...           ...  ...   ...     ...  ...
# 42 2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away       0  0.0
# 44 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away       0  2.0
# 46 2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home       0  2.0
# 49 2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home       0  3.0
# 50 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home       0  5.0
#
# ...

# %%
#Applying on function to each team essentialy

matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 32 2022-03-13  14:00  Premier League  Matchweek 29
#                         33 2022-03-18  20:00  Premier League  Matchweek 30
#                         34 2022-04-02  15:00  Premier League  Matchweek 31
#                         35 2022-04-08  20:00  Premier League  Matchweek 32
#                         36 2022-04-24  14:00  Premier League  Matchweek 34
#
# ...

# %%
#Drop extra index level

matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#          date   time            comp         round  day venue  result   gf  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home       0  2.0
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away       0  0.0
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home       0  0.0
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away       0  1.0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home       0  0.0
# ..        ...    ...             ...           ...  ...   ...     ...  ...
# 32 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away       0  1.0
# 33 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home       0  2.0
# 34 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home       0  2.0
# 35 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away       0  0.0
# 36 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away       0  0.0
#
# ...

# %%
#Assign values from zero to 1316 (we did unique values for each index)

matches_rolling.index = range(matches_rolling.shape[0])

# %%
#Creating a function what will help to make predictions easier (it includes all written code but in one function)

def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
#Adding new predictior what we created

combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
#Looking for an error. It is better now 

error
# Out:
# 0.625

# %%
#We can see where misprediction exactly are 

combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       date     team        opponent  result
# 55       0          0 2022-01-23  Arsenal         Burnley       0
# 56       1          0 2022-02-10  Arsenal          Wolves       0
# 57       1          0 2022-02-19  Arsenal       Brentford       0
# 58       1          1 2022-02-24  Arsenal          Wolves       0
# 59       1          1 2022-03-06  Arsenal         Watford       0
# 60       1          1 2022-03-13  Arsenal  Leicester City       0
# 61       0          1 2022-03-16  Arsenal       Liverpool       0
# 62       1          0 2022-03-19  Arsenal     Aston Villa       0
# 63       0          0 2022-04-04  Arsenal  Crystal Palace       0
# 64       0          0 2022-04-09  Arsenal        Brighton       0

# %%
#By using this class we can avoid any misunderstandings in names. Doing it by pandas map method

class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
#Using created class on dataframe

combined["new_team"] = combined["team"].map(mapping)

# %%
#Merging DataFrame with itself. I want to see if predictions match up on both sides 

merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])
merged
# Out:
#      actual_x  predicted_x       date                   team_x     opponent_x  \
# 0           0            0 2022-01-23                  Arsenal        Burnley
# 1           1            0 2022-02-10                  Arsenal         Wolves
# 2           1            0 2022-02-19                  Arsenal      Brentford
# 3           1            1 2022-02-24                  Arsenal         Wolves
# 4           1            1 2022-03-06                  Arsenal        Watford
# ..        ...          ...        ...                      ...            ...
# 257         1            0 2022-03-13  Wolverhampton Wanderers        Everton
# 258         0            0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 259         1            0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 260         0            0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 261         0            0 2022-04-24  Wolverhampton Wanderers        Burnley
#
# ...

# %%
#Looking for all rows where one team predicted to win and other predicted to lose, it helps algorithm to be more confident in

merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    27
# 0    13
# Name: actual_x, dtype: int64

# %%
#Accuracy is about 67%

27/40
# Out:
# 0.675
